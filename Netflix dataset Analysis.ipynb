# %%
#importing the data

import pandas as pd
data=pd.read_csv(r'C:\Users\k.tarakaramu\Downloads\NetFlix.csv.zip')

# %%
data
# Out:
#      show_id     type                                      title  \
# 0         s1  TV Show                                         3%
# 1        s10    Movie                                       1920
# 2       s100    Movie                                 3 Heroines
# 3      s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4      s1001  TV Show                             Blue Planet II
# ...      ...      ...                                        ...
# 7782    s995  TV Show                                 Blown Away
# 7783    s996  TV Show                              Blue Exorcist
# 7784    s997    Movie                  Blue Is the Warmest Color
# 7785    s998    Movie                               Blue Jasmine
# 7786    s999    Movie                                   Blue Jay
#
#                  director                                               cast  \
# 0                     NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.shape
# Out:
# (7787, 12)

# %%
data.size
# Out:
# 93444

# %%
data.columns # shows the title of the columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genres', 'description'],
#       dtype='object')

# %%
data.dtypes #shows the datatypes of each columns
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration         int64
# genres          object
# description     object
# dtype: object

# %%
data.value_counts()
# Out:
# show_id  type     title                              director                                                                      cast                                                                                                                                                                                    country                        date_added  release_year  rating  duration  genres                                              description
# ...

# %%
data[data.duplicated()] #shows any duplicated data
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, genres, description]
# Index: []

# %%
data.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False      True  False    False       False
# 1       False  False  False     False  False    False       False
# 2       False  False  False     False  False    False       False
# 3       False  False  False     False  False    False       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 7782    False  False  False      True   True    False       False
# 7783    False  False  False      True  False    False       False
# 7784    False  False  False     False  False    False       False
# 7785    False  False  False     False  False    False       False
# 7786    False  False  False     False  False    False       False
#
#       release_year  rating  duration  genres  description
# 0            False   False     False   False        False
# ...

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# genres             0
# description        0
# dtype: int64

# %%
#Try to show the data using heat-map
import seaborn as sns
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#Checking the director Vikram Bhatt movies
data[data['director'].isin(['Vikram Bhatt'])]
# Out:
#   show_id   type title      director  \
# 1     s10  Movie  1920  Vikram Bhatt
#
#                                                 cast country date_added  \
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...   India  15-Dec-17
#
#    release_year rating  duration  \
# 1          2008  TV-MA       143
#
#                                            genres  \
# 1  Horror Movies, International Movies, Thrillers
#
#                                          description
# 1  An architect and his wife move into a castle t...

# %%
#To show which year has the highest number of releases

data['Data_N'] = pd.to_datetime(data['release_year'])
data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
data['Date_N'].dt.year.value_counts()#It counts the occurences of all individual years in Date column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date_N'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 data['Date_N'].dt.year.value_counts()
#
# ...

# %%
data.groupby('type').type.count()
# Out:
# type
# Movie      5377
# TV Show    2410
# Name: type, dtype: int64

# %%
#To show the movies release in the specific year
data[(data['type']=='Movie') & (data['release_year']==2000)]
# Out:
#      show_id   type                                              title  \
# 287    s1257  Movie                                       Center Stage
# 294    s1263  Movie                                     Chal Mere Bhai
# 314    s1281  Movie                                   Charlie's Angels
# 609    s1547  Movie                     Crouching Tiger, Hidden Dragon
# 948    s1852  Movie                       Dragonheart: A New Beginning
# 1295   s2164  Movie                                  Final Destination
# 1337   s2201  Movie                                               Fiza
# 1766   s2589  Movie                          Hamara Dil Aapke Paas Hai
# 2046   s2840  Movie                     How the Grinch Stole Christmas
# 2471   s3222  Movie                             Joseph: King of Dreams
# 2754   s3478  Movie                                          Kya Kehna
# 2964   s3667  Movie                                       Little Nicky
# ...

# %%
data[(data['type']=='Movie') & (data['release_year']==2000)].count() # Checking the number of count
# Out:
# show_id         30
# type            30
# title           30
# director        30
# cast            30
# country         30
# date_added      30
# release_year    30
# rating          30
# duration        30
# genres          30
# description     30
# Data_N          30
# dtype: int64

# %%
 #Shows the movies or tvshows released in India
    
data[(data['country']=='India')] ['title']
# Out:
# 1               1920
# 8       BluffMaster!
# 13          3 Idiots
# 21             Bobby
# 22      Bobby Jasoos
#             ...
# 7714        Bioscope
# 7726     Bittoo Boss
# 7727           Black
# 7734    Black Friday
# 7774     Blood Money
# Name: title, Length: 923, dtype: object

# %%
#To show the number of movies or tvshows released by a country
data['country'].value_counts()
# Out:
# country
# United States                             2555
# India                                      923
# United Kingdom                             397
# Japan                                      226
# South Korea                                183
#                                           ...
# Argentina, United States, Mexico             1
# Canada, Germany, France, United States       1
# Soviet Union, India                          1
# Taiwan, China, France, United States         1
# France, Belgium, Spain                       1
# Name: count, Length: 681, dtype: int64

# %%
data['director'].value_counts()
# Out:
# director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
#                           ..
# Mariano Baez               1
# Ravikanth Perepu           1
# Santram Varma              1
# Oliver Blackburn           1
# Woody Allen                1
# Name: count, Length: 4049, dtype: int64

# %%
data[(data['title']=='TV Show')&(data['type']=='Comedies, Dramas, International Movies')]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, genres, description, Data_N]
# Index: []

# %%
data[(data['title']=='TV Show')&(data['type']=='Comedies, Dramas, International Movies') | (data['Country'=='India'])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ...

# %%
data_new=data.dropna()

# %%
data_new
# Out:
#      show_id   type                                      title  \
# 1        s10  Movie                                       1920
# 2       s100  Movie                                 3 Heroines
# 3      s1000  Movie  Blue Mountain State: The Rise of Thadland
# 5      s1002  Movie                                  Blue Ruin
# 6      s1003  Movie                                Blue Streak
# ...      ...    ...                                        ...
# 7778    s991  Movie                            Blood Will Tell
# 7781    s994  Movie                                       Blow
# 7784    s997  Movie                  Blue Is the Warmest Color
# 7785    s998  Movie                               Blue Jasmine
# 7786    s999  Movie                                   Blue Jay
#
#                         director  \
# 1                   Vikram Bhatt
# 2                 Iman Brotoseno
# 3                   Lev L. Spiro
# 5                Jeremy Saulnier
# 6                   Les Mayfield
# ...

# %%
#To check the actor tomcruise acted in how many films
data_new[data_new['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 3180   s3861  Movie  Magnolia  Paul Thomas Anderson
# 4525   s5071  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 3180  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 4525  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      date_added  release_year rating  duration                      genres  \
# 3180   1-Jan-20          1999      R       189  Dramas, Independent Movies
# 4525   1-Jul-19          1988      R       134      Classic Movies, Dramas
#
#                                             description  \
# 3180  Through chance, human action, past history and...
# 4525  A fast-talking yuppie is forced to slow down w...
#
#                             Data_N
# 3180 1970-01-01 00:00:00.000001999
# 4525 1970-01-01 00:00:00.000001988

# %%
data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
#Gives the unique values of the column 'rating' 
data['rating'].unique()
# Out:
# array(['TV-MA', 'TV-PG', 'R', 'TV-G', 'PG-13', 'TV-14', 'TV-Y', 'PG',
#        'TV-Y7', 'NR', 'G', 'TV-Y7-FV', nan, 'UR', 'NC-17'], dtype=object)

# %%
#Gives the number of unique values of the column 'rating
data['rating'].nunique()
# Out:
# 14

# %%
#To check how many movies got the 'R' rating in United States
data[(data['type']=='Movie') & (data['rating']=='R') & (data['country']=='United States')]
# Out:
#      show_id   type                                      title  \
# 3      s1000  Movie  Blue Mountain State: The Rise of Thadland
# 7      s1004  Movie                             Blue Valentine
# 49     s1042  Movie                           Bonnie and Clyde
# 57      s105  Movie                         30 Minutes or Less
# 110    s1098  Movie                                      Brick
# ...      ...    ...                                        ...
# 7720    s939  Movie                                      Bitch
# 7748    s964  Movie                           Black Snake Moan
# 7757    s972  Movie                                      Blaze
# 7762    s977  Movie                             Bleed for This
# 7781    s994  Movie                                       Blow
#
#               director                                               cast  \
# 3         Lev L. Spiro  Alan Ritchson, Darin Brooks, James Cade, Rob R...
# ...

# %%
#To check how many TV Shows got R rated after the year 2020 

data[(data['title']=='TV Show') & (data['rating']=='R') |(data['release_year'] >=2020) ]
# Out:
#      show_id     type                        title      director  \
# 0         s1  TV Show                           3%           NaN
# 10     s1007  TV Show                          BNA           NaN
# 20     s1016    Movie        Bobbleheads The Movie     Kirk Wise
# 31     s1026  TV Show              BoJack Horseman           NaN
# 52     s1045  TV Show                    Bookmarks           NaN
# ...      ...      ...                          ...           ...
# 7753    s969    Movie  BLACKPINK: Light Up the Sky  Caroline Suh
# 7767    s981  TV Show                 Bling Empire           NaN
# 7772    s986  TV Show                Blood & Water           NaN
# 7775    s989  TV Show                Blood of Zeus           NaN
# 7780    s993  TV Show                    Bloodride           NaN
#
#                                                    cast        country  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# ...

# %%
#To check maximum duration of a movie on Netflix

data.duration.max()
# Out:
# 312

# %%
#To check the which country has more number of movies released
data_tvshow=data[data['type']=='TV Show']
data_tvshow.country.value_counts()
# Out:
# country
# United States                                  705
# United Kingdom                                 204
# Japan                                          157
# South Korea                                    147
# India                                           71
#                                               ...
# Uruguay, Germany                                 1
# China, United Kingdom                            1
# South Korea, France                              1
# Norway, United States                            1
# Saudi Arabia, Syria, Egypt, Lebanon, Kuwait      1
# Name: count, Length: 183, dtype: int64

# %%
data_tvshow
# Out:
#      show_id     type                           title director  \
# 0         s1  TV Show                              3%      NaN
# 4      s1001  TV Show                  Blue Planet II      NaN
# 10     s1007  TV Show                             BNA      NaN
# 15     s1011  TV Show                   Bo on the Go!      NaN
# 17     s1013  TV Show  Bob Ross: Beauty Is Everywhere      NaN
# ...      ...      ...                             ...      ...
# 7777    s990  TV Show                      Blood Pact      NaN
# 7779    s992  TV Show                       Bloodline      NaN
# 7780    s993  TV Show                       Bloodride      NaN
# 7782    s995  TV Show                      Blown Away      NaN
# 7783    s996  TV Show                   Blue Exorcist      NaN
#
#                                                    cast         country  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# ...

# %%
# Out:
# country
# United States                                  705
# United Kingdom                                 204
# Japan                                          157
# South Korea                                    147
# India                                           71
#                                               ...
# Uruguay, Germany                                 1
# China, United Kingdom                            1
# South Korea, France                              1
# Norway, United States                            1
# Saudi Arabia, Syria, Egypt, Lebanon, Kuwait      1
# Name: count, Length: 183, dtype: int64

# %%
#Sorting the data by year
data.sort_values(by = 'release_year', ascending = False).head()
# Out:
#      show_id     type                                              title  \
# 492    s1441  TV Show                                          Cobra Kai
# 250    s1223  TV Show                                    Carmen Sandiego
# 397    s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# 1937   s2742  TV Show                                              Hilda
# 3769   s4391  TV Show                                  Nailed It! Mexico
#
#         director                                               cast  \
# 492          NaN  Ralph Macchio, William Zabka, Xolo Maridueña, ...
# 250          NaN  Gina Rodriguez, Finn Wolfhard, Abby Trott, Mic...
# 397   Chris Rock                                         Chris Rock
# 1937         NaN  Bella Ramsey, Ameerah Falzon-Ojo, Oliver Nelso...
# 3769         NaN                           Omar Chaparro, Anna Ruiz
#
#                                     country date_added  release_year rating  \
# ...
